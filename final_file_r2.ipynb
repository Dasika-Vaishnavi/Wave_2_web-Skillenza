# %%
import pandas as pd
import numpy as np
import datetime as dt

data = pd.read_csv(r"C:\Users\sandhya rani\Downloads\TM_models\KSR_dam_final_f.csv")

# %%
data =data[:2980]

# %%
data
# Out:
#        SNO   FLOW_DATE  PRESENT_STORAGE_TMC  RES_LEVEL_FT  INFLOW_CUSECS  \
# 0        0  01-01-2011                46.42        122.59           2029
# 1        1  02-01-2011                46.54        122.68           3084
# 2        2  03-01-2011                46.64        122.75           2776
# 3        3  04-01-2011                46.69        122.79           2311
# 4        4  05-01-2011                46.70        122.80           1847
# ...    ...         ...                  ...           ...            ...
# 2975  2975  31-01-2013                11.44         81.45            358
# 2976  2976  01-02-2013                11.43         81.43            304
# 2977  2977  02-02-2013                12.14         82.93           1145
# 2978  2978  03-02-2013                11.42         81.41            353
# 2979  2979  04-02-2013                11.41         81.39            305
#
#       OUTFLOW_CUECS  UNIQUE_KEY        date  min       max     mean     stdev
# 0              2000  01-01-2011  01-01-2011  0.0  0.000000  0.00000  0.000000
# 1              1490  02-01-2011  02-01-2011  0.0  0.272601  0.01997  0.062387
# 2              1491  03-01-2011  03-01-2011  0.0  0.000000  0.00000  0.000000
# 3              1491  04-01-2011  04-01-2011  0.0  0.000000  0.00000  0.000000
# 4              1491  05-01-2011  05-01-2011  0.0  0.000000  0.00000  0.000000
# ...             ...         ...         ...  ...       ...      ...       ...
# 2975            348  31-01-2013  31-01-2013  0.0  0.000000  0.00000  0.000000
# 2976            348  01-02-2013  01-02-2013  0.0  0.000000  0.00000  0.000000
# 2977            357  02-02-2013  02-02-2013  0.0  0.000000  0.00000  0.000000
# 2978            348  03-02-2013  03-02-2013  0.0  0.000000  0.00000  0.000000
# 2979            348  04-02-2013  04-02-2013  0.0  0.000000  0.00000  0.000000
#
# [2980 rows x 12 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import datetime
import sklearn as sk
import matplotlib.pyplot as plt
import matplotlib.path as pt
import warnings
from sklearn import pipeline,preprocessing,metrics,model_selection,ensemble
from sklearn_pandas import DataFrameMapper


from sklearn.metrics import r2_score
import numpy as np
X = data["mean"]
Y = data['RES_LEVEL_FT']
X,Y
# Out:
# (0       0.00000
#  1       0.01997
#  2       0.00000
#  3       0.00000
#  4       0.00000
#           ...
#  2975    0.00000
#  2976    0.00000
#  2977    0.00000
#  2978    0.00000
#  2979    0.00000
#  Name: mean, Length: 2980, dtype: float64,
#  0       122.59
#  1       122.68
#  2       122.75
#  3       122.79
#  4       122.80
#           ...
#  2975     81.45
#  2976     81.43
#  2977     82.93
#  2978     81.41
#  2979     81.39
#  Name: RES_LEVEL_FT, Length: 2980, dtype: float64)

# %%
train_x = X[:1800]
train_y = Y[:1800]
test_x = X[1800:]
test_y = Y[1800:]
my_model = np.poly1d(np.polyfit(train_x,train_y,2))
r2 =r2_score(test_y,(my_model(test_x)))
print(r2)
plt.scatter(X,Y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-16-976b56d79243> in <module>
#       3 test_x = X[1800:]
#       4 test_y = Y[1800:]
# ----> 5 my_model = np.poly1d(np.polyfit(train_x,train_y,2))
#       6 r2 =r2_score(test_y,(my_model(test_x)))
#       7 print(r2)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     627     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     628     lhs /= scale
# --> 629     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     630     c = (c.T/scale).T  # broadcast scale coefficients
#     631
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in lstsq(a, b, rcond)
#    2304         # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2305         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2306     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2307     if m == 0:
#    2308         x[...] = 0
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_lstsq(err, flag)
#      98
#      99 def _raise_linalgerror_lstsq(err, flag):
# --> 100     raise LinAlgError("SVD did not converge in Linear Least Squares")
#     101
#     102 def get_linalg_error_extobj(callback):
#
# LinAlgError: SVD did not converge in Linear Least Squares
